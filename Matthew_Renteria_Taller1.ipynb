# %% [markdown]
# <a href="https://colab.research.google.com/github/matthewrenteria/Visualizacion-de-datos-2022/blob/main/Matthew_Renteria_Taller1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Taller 1 visualizacion de datos
# Matthew Rentería

# %% [markdown]
# # Visualización 1: "Rompiendo el misterio de la forma de los huevos"
# **1. Gráfica 1:** En esta gráfica se observan 3 variaciones y en esta se nos muestra la población estudiada (gráfica 1), a que grupo pertenece (gráfica 2) y de ese grupo cuantas especies pertenecen a este (gráfica 3).
#
# ![Imagen 1 vd.jpg](data:image/jpeg;base64,...)
# ![Imagen 2 vd.jpg.png](data:image/png;base64,...)
# ![Imagen 3 vd.jpg](data:image/jpeg;base64,...)
#
#    1. **Análisis del qué:** Se observa que el tipo de dato es de **geométricos**, su disponibilidad es **estática** y el tipo de atributo es **cuantitativo**.
#    2. **Análisis del porque:** Se observa que se busca **anotar**, **identificar** y **comparar** los tipos de huevos y ver en cual hay una mayor población.
#    3. **Análisis del como:** Se observa que es un **arreglo** en **separación**.
#    4. **Análisis de marca y canal:** Se observa que posee un canal de posición espacial tanto horizontal como vertical, mientras que posee marcas tanto de puntos como de áreas.
#    5. **Cumplimiento de las reglas:** Se destaca que se cumple satisfactoriamente con todas las reglas ya que no hay un uso innecesario del 3D y un uso correcto del 2D ademas de no saturar la gráfica con los nombres de todas las divisiones de las especies de aves sino solo mostrando aquellas con mayor población.

# %% [markdown]
# **2. Gráfica 2:** Se analiza la forma de los huevos tomando como eje X su asimetria y en el eje Y su elipticidad (Imagen 1), luego se obsevan los casos mas atipicos junto con imagenes de los huevos (Imagen 2) y finalmente cuales son algunas de las aves a las que les pertenecen esos huevos (Imagen 3).
#
# ![Imagen 4.jpg](data:image/jpeg;base64,...)
# ![Imagen 5.jpg](data:image/jpeg;base64,...)
# ![Imagen 6.jpg](data:image/jpeg;base64,...)
#    1. **Análisis del qué:** Se observa que el tipo de dato es de **clusters**, su disponibilidad es **estática** y el tipo de atributo es **sequencial**.
#    2. **Análisis del porque:** Se observa que se busca **identificar** y señalar **outliers** entre los tipos de huevos.
#    3. **Análisis del como:** Se observa que es un **arreglo** en un **orden** específico y buscando **seleccionar** los datos atípicos.
#    4. **Análisis de marca y canal:** Se observa que posee un canal de posición espacial tanto horizontal como vertical, mientras que posee marca de punto.
#    5. **Cumplimiento de las reglas:** Se puede decir al igual que con la anterior gráfica se cumple satisfactoriamente con todas las reglas ya que no hay un uso innecesario del 3D y un uso correcto del 2D además de no saturar la grafica con los nombres de todas las  aves sino solo mostrando aquellas´que eran consideradas atípicas.

# %% [markdown]
# **3. Gráfica 3:** En esta gráfica se busca señalar la relación entre un alto HWI (un indicador del desempeño del vuelo en aves) y la asimetría y la elipticidad de los huevos.
# ![Imagen 7.jpg](data:image/jpeg;base64,...)
#
#    1. **Análisis del qué:** Se observa que el tipo de dato es de **networks**, su disponibilidad es **estatica** y el tipo de atributo es **ordinal** con orden **divergente**.
#    2. **Análisis del porque:** Se observa que se busca **identificar**, **comparar** y señalar **dependencia** entre el nivel de HWI y su asimetría y elipticidad.
#    3. **Análisis del como:** Se observa que es un **arreglo** en un **orden** y **alineamiento** específico y buscando **navegar** sobre la información de los huevos presentados.
#    4. **Análisis de marca y canal:** Se observa que posee un canal de posición espacial tanto horizontal como vertical, mientras que posee marcas de linea y de punto.
#    5. **Cumplimiento de las reglas:** Se puede decir al igual que con las anteriores gráficas se cumple satisfactoriamente con todas las reglas ya que no hay saturación de las gráficas con múltiples ejemplos de aves sino solo mostrando ejemplos muy puntuales.

# %% [markdown]
# # Visualización 2: Proyecto de ley de salud de Trump y sus consecuencias.
#
# La siguente gráfica consiste en una representación condado por condado de como los recortes en el seguro de salud estatal realizados por el expresidente Donald Trump los llegan a afectar y así mismo el que tanto apoyo tuvo el gobernante en ese lugar.
#
# ![Imagen 9.jpg](data:image/jpeg;base64,...)
# ![Imagen 8.jpg](data:image/jpeg;base64,...)
#
#    1. **Análisis del qué:** Se observa que el tipo de dato es de **fields**, su disponibilidad es **estática** y el tipo de atributo es **categórico**.
#    2. **Analisis del porqué:** Se observa que se busca **identificar** y **comparar** los estados más afectados por la política de Trump y así mismo el si estos lugares poseen un alto porcentaje de seguidores del mandatario y su forma de visualizarse es a través de un **Spatial data**.
#    3. **Análisis del como:** Se observa que es un **arreglo** en un **Spatial data** y buscando diferenciar a través de un **color** específico la influencia negativa de las medidas de salud pubica y su apoyo en ese sitio.
#    4. **Análisis de marca y canal:** Se observa que posee un canal de posición espacial tanto horizontal como vertical así mismo se maneja un canal de color, mientras que posee marcas de área.
#    5. **Cumplimiento de las reglas:** Se puede decir que se cumple satisfactoriamente con todas las reglas ya que no hay saturación de color en la gráfica, los colores para diferenciar cada uno son bastantes claros y así mismo el uso de leyendas es bastante intuitivo y comprensible para saber a que se esta refiriendo.

# %% [markdown]
# # Bibliografía
#
# 1. https://www.visualisingdata.com/2017/07/best-visualisation-web-june-2017/
# 2. https://vis.sciencemag.org/eggs/
# 3. https://qz.com/1008167/map-donald-trumps-mean-mean-mean-health-care-bill-is-meanest-to-his-most-crucial-voters/
