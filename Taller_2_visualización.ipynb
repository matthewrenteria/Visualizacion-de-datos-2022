# %% [markdown]
# <a href="https://colab.research.google.com/github/matthewrenteria/Visualizacion-de-datos-2022/blob/main/Taller_2_visualizaci%C3%B3n.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Taller visualización de datos
# Matthew Enrique Rentería Guzmán

# %% [markdown]
# ## Punto 1

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None) #Mostrar todas las columnas

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df_SECOP = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/SECOP_II_-_Procesos_de_Contrataci_n.csv', 
                 sep = ',',
                 index_col=0,
                 dtype={
                     'Nit Entidad': str
                 })
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (15,16,17) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df_SECOP.dtypes
# Out:
# Nit Entidad                                               object
# Departamento Entidad                                      object
# Ciudad Entidad                                            object
# OrdenEntidad                                              object
# Entidad Centralizada                                      object
# ID del Proceso                                            object
# Referencia del Proceso                                    object
# PCI                                                       object
# ID del Portafolio                                         object
# Nombre del Procedimiento                                  object
# Descripción del Procedimiento                             object
# Fase                                                      object
# Fecha de Publicacion del Proceso                          object
# Fecha de Ultima Publicación                               object
# Fecha de Publicacion (Fase Planeacion Precalificacion)    object
# Fecha de Publicacion (Fase Seleccion Precalificacion)     object
# Fecha de Publicacion (Manifestacion de Interes)           object
# Fecha de Publicacion (Fase Borrador)                      object
# Fecha de Publicacion (Fase Seleccion)                     object
# Precio Base                                                int64
# Modalidad de Contratacion                                 object
# Justificación Modalidad de Contratación                   object
# Duracion                                                   int64
# Unidad de Duracion                                        object
# Fecha de Recepcion de Respuestas                          object
# Fecha de Apertura de Respuesta                            object
# Fecha de Apertura Efectiva                                object
# Ciudad de la Unidad de Contratación                       object
# Nombre de la Unidad de Contratación                       object
# Proveedores Invitados                                      int64
# Proveedores con Invitacion Directa                         int64
# Visualizaciones del Procedimiento                          int64
# Proveedores que Manifestaron Interes                       int64
# Respuestas al Procedimiento                                int64
# Respuestas Externas                                        int64
# Conteo de Respuestas a Ofertas                             int64
# Proveedores Unicos con Respuestas                          int64
# Numero de Lotes                                            int64
# Estado del Procedimiento                                  object
# ID Estado del Procedimiento                                int64
# Adjudicado                                                object
# ID Adjudicacion                                           object
# CodigoProveedor                                           object
# Departamento Proveedor                                    object
# Ciudad Proveedor                                          object
# Fecha Adjudicacion                                        object
# Valor Total Adjudicacion                                   int64
# Nombre del Adjudicador                                    object
# Nombre del Proveedor Adjudicado                           object
# NIT del Proveedor Adjudicado                              object
# Codigo Principal de Categoria                             object
# Estado de Apertura del Proceso                            object
# Tipo de Contrato                                          object
# Subtipo de Contrato                                       object
# Categorias Adicionales                                    object
# URLProceso                                                object
# Codigo Entidad                                             int64
# dtype: object

# %%
df_SECOP['Fecha de Ultima Publicación'].isnull()
# Out:
# Entidad
# DISPENSARIO MEDICO DE MEDELLÍN                            False
# DIRECCION DE SANIDAD EJERCITO DISPENSARIO MEDICO YOPAL    False
# INDUSTRIA MILITAR                                         False
# MINISTERIO DE VIVIENDA. CIUDAD Y TERRITORIO               False
# HOSPITAL CENTRAL                                          False
#                                                           ...
# MINISTERIO DE CULTURA                                     False
# SENA HOTELERIA TURISMO Y ALIMENTOS                        False
# MINISTERIO DEL INTERIOR                                   False
# PERSONERIA DE BOGOTA                                      False
# COMPLEJO CARCELARIO Y PENITENCIARIO DE IBAGUE PICALEÑA    False
# Name: Fecha de Ultima Publicación, Length: 876768, dtype: bool

# %%
df_SECOP['Fecha de Publicacion del Proceso'].isnull()
# Out:
# Entidad
# DISPENSARIO MEDICO DE MEDELLÍN                            False
# DIRECCION DE SANIDAD EJERCITO DISPENSARIO MEDICO YOPAL    False
# INDUSTRIA MILITAR                                         False
# MINISTERIO DE VIVIENDA. CIUDAD Y TERRITORIO               False
# HOSPITAL CENTRAL                                          False
#                                                           ...
# MINISTERIO DE CULTURA                                     False
# SENA HOTELERIA TURISMO Y ALIMENTOS                        False
# MINISTERIO DEL INTERIOR                                   False
# PERSONERIA DE BOGOTA                                      False
# COMPLEJO CARCELARIO Y PENITENCIARIO DE IBAGUE PICALEÑA    False
# Name: Fecha de Publicacion del Proceso, Length: 876768, dtype: bool

# %%
df_SECOP['Fecha de Ultima Publicación'].isnull().sum()
# Out:
# 2

# %%
df_SECOP['Fecha de Publicacion del Proceso'].isnull().sum()
# Out:
# 2

# %%
df_SECOP[df_SECOP["Fecha de Ultima Publicación"].isnull() == True]
# Out:
#                      Nit Entidad        Departamento Entidad Ciudad Entidad  \
# Entidad
# GOBERNACION DE SUCRE   892280021                 No Definido    No Definido
# DGSM-DISAN-ARC-HONAC  8300396705  Distrito Capital de Bogotá         Bogotá
#
#                      OrdenEntidad Entidad Centralizada   ID del Proceso  \
# Entidad
# GOBERNACION DE SUCRE  Territorial                   No  CO1.REQ.1857691
# DGSM-DISAN-ARC-HONAC     Nacional                   Si  CO1.REQ.1860431
#
#                           Referencia del Proceso           PCI  \
# Entidad
# GOBERNACION DE SUCRE             CP-SSD-359-2021            ND
# DGSM-DISAN-ARC-HONAC  211-MDN -DISAN-HONAC- 2021  15-01-11-057
#
#                      ID del Portafolio               Nombre del Procedimiento  \
# Entidad
# GOBERNACION DE SUCRE  CO1.BDOS.1807553  PRESTACION DE SERVICIOS PROFESIONALES
# DGSM-DISAN-ARC-HONAC  CO1.BDOS.1810121            ENFERMERA PROFESIONAL HONAC
#
#                                           Descripción del Procedimiento  \
# Entidad
# GOBERNACION DE SUCRE  PRESTACIÓN DE SERVICIOS PROFESIONALES DE UNA F...
# DGSM-DISAN-ARC-HONAC  PRESTACIÓN DE SERVICIOS PROFESIONALES COMO ENF...
#
#                                         Fase Fecha de Publicacion del Proceso  \
# Entidad
# GOBERNACION DE SUCRE  Presentación de oferta                              NaN
# DGSM-DISAN-ARC-HONAC  Presentación de oferta                              NaN
#
#                      Fecha de Ultima Publicación  \
# Entidad
# GOBERNACION DE SUCRE                         NaN
# DGSM-DISAN-ARC-HONAC                         NaN
#
#                      Fecha de Publicacion (Fase Planeacion Precalificacion)  \
# Entidad
# GOBERNACION DE SUCRE                                                NaN
# DGSM-DISAN-ARC-HONAC                                                NaN
#
#                      Fecha de Publicacion (Fase Seleccion Precalificacion)  \
# Entidad
# GOBERNACION DE SUCRE                                                NaN
# DGSM-DISAN-ARC-HONAC                                                NaN
#
#                      Fecha de Publicacion (Manifestacion de Interes)  \
# Entidad
# GOBERNACION DE SUCRE                                             NaN
# DGSM-DISAN-ARC-HONAC                                             NaN
#
#                      Fecha de Publicacion (Fase Borrador)  \
# Entidad
# GOBERNACION DE SUCRE                                  NaN
# DGSM-DISAN-ARC-HONAC                                  NaN
#
#                      Fecha de Publicacion (Fase Seleccion)  Precio Base  \
# Entidad
# GOBERNACION DE SUCRE                                   NaN     12000000
# DGSM-DISAN-ARC-HONAC                                   NaN      9360000
#
#                      Modalidad de Contratacion  \
# Entidad
# GOBERNACION DE SUCRE      Contratación directa
# DGSM-DISAN-ARC-HONAC      Contratación directa
#
#                      Justificación Modalidad de Contratación  Duracion  \
# Entidad
# GOBERNACION DE SUCRE                  ServiciosProfesionales         4
# DGSM-DISAN-ARC-HONAC                  ServiciosProfesionales         4
#
#                      Unidad de Duracion Fecha de Recepcion de Respuestas  \
# Entidad
# GOBERNACION DE SUCRE              Meses                              NaN
# DGSM-DISAN-ARC-HONAC              Meses                              NaN
#
#                      Fecha de Apertura de Respuesta  \
# Entidad
# GOBERNACION DE SUCRE                            NaN
# DGSM-DISAN-ARC-HONAC                            NaN
#
#                      Fecha de Apertura Efectiva  \
# Entidad
# GOBERNACION DE SUCRE                        NaN
# DGSM-DISAN-ARC-HONAC                        NaN
#
#                      Ciudad de la Unidad de Contratación  \
# Entidad
# GOBERNACION DE SUCRE                           Sincelejo
# DGSM-DISAN-ARC-HONAC                           Cartagena
#
#                      Nombre de la Unidad de Contratación  \
# Entidad
# GOBERNACION DE SUCRE                 Secretaria de Salud
# DGSM-DISAN-ARC-HONAC                  grupo de contratos
#
#                       Proveedores Invitados  \
# Entidad
# GOBERNACION DE SUCRE                      0
# DGSM-DISAN-ARC-HONAC                      0
#
#                       Proveedores con Invitacion Directa  \
# Entidad
# GOBERNACION DE SUCRE                                   0
# DGSM-DISAN-ARC-HONAC                                   0
#
#                       Visualizaciones del Procedimiento  \
# Entidad
# GOBERNACION DE SUCRE                                  0
# DGSM-DISAN-ARC-HONAC                                  0
#
#                       Proveedores que Manifestaron Interes  \
# Entidad
# GOBERNACION DE SUCRE                                     0
# DGSM-DISAN-ARC-HONAC                                     0
#
#                       Respuestas al Procedimiento  Respuestas Externas  \
# Entidad
# GOBERNACION DE SUCRE                            0                    0
# DGSM-DISAN-ARC-HONAC                            0                    0
#
#                       Conteo de Respuestas a Ofertas  \
# Entidad
# GOBERNACION DE SUCRE                               0
# DGSM-DISAN-ARC-HONAC                               0
#
#                       Proveedores Unicos con Respuestas  Numero de Lotes  \
# Entidad
# GOBERNACION DE SUCRE                                  0                0
# DGSM-DISAN-ARC-HONAC                                  0                0
#
#                      Estado del Procedimiento  ID Estado del Procedimiento  \
# Entidad
# GOBERNACION DE SUCRE              No Definido                           50
# DGSM-DISAN-ARC-HONAC              No Definido                           50
#
#                      Adjudicado ID Adjudicacion CodigoProveedor  \
# Entidad
# GOBERNACION DE SUCRE         No   No Adjudicado   No Adjudicado
# DGSM-DISAN-ARC-HONAC         No   No Adjudicado   No Adjudicado
#
#                      Departamento Proveedor Ciudad Proveedor  \
# Entidad
# GOBERNACION DE SUCRE              No aplica        No aplica
# DGSM-DISAN-ARC-HONAC              No aplica        No aplica
#
#                      Fecha Adjudicacion  Valor Total Adjudicacion  \
# Entidad
# GOBERNACION DE SUCRE                NaN                         0
# DGSM-DISAN-ARC-HONAC                NaN                         0
#
#                      Nombre del Adjudicador Nombre del Proveedor Adjudicado  \
# Entidad
# GOBERNACION DE SUCRE          No Adjudicado                   No Adjudicado
# DGSM-DISAN-ARC-HONAC          No Adjudicado                   No Adjudicado
#
#                      NIT del Proveedor Adjudicado  \
# Entidad
# GOBERNACION DE SUCRE                No Adjudicado
# DGSM-DISAN-ARC-HONAC                No Adjudicado
#
#                      Codigo Principal de Categoria  \
# Entidad
# GOBERNACION DE SUCRE                   V1.80111600
# DGSM-DISAN-ARC-HONAC                   V1.85101601
#
#                      Estado de Apertura del Proceso  \
# Entidad
# GOBERNACION DE SUCRE                        Abierto
# DGSM-DISAN-ARC-HONAC                        Abierto
#
#                                     Tipo de Contrato Subtipo de Contrato  \
# Entidad
# GOBERNACION DE SUCRE  Servicios de aprovisionamiento     No Especificado
# DGSM-DISAN-ARC-HONAC  Servicios de aprovisionamiento     No Especificado
#
#                      Categorias Adicionales  \
# Entidad
# GOBERNACION DE SUCRE                     ND
# DGSM-DISAN-ARC-HONAC                     ND
#
#                                                              URLProceso  \
# Entidad
# GOBERNACION DE SUCRE  https://community.secop.gov.co/Public/Tenderin...
# DGSM-DISAN-ARC-HONAC  https://community.secop.gov.co/Public/Tenderin...
#
#                       Codigo Entidad
# Entidad
# GOBERNACION DE SUCRE       705153054
# DGSM-DISAN-ARC-HONAC       701724114

# %%
df_SECOP[df_SECOP["Fecha de Publicacion del Proceso"].isnull() == True]
# Out:
#                      Nit Entidad        Departamento Entidad Ciudad Entidad  \
# Entidad
# GOBERNACION DE SUCRE   892280021                 No Definido    No Definido
# DGSM-DISAN-ARC-HONAC  8300396705  Distrito Capital de Bogotá         Bogotá
#
#                      OrdenEntidad Entidad Centralizada   ID del Proceso  \
# Entidad
# GOBERNACION DE SUCRE  Territorial                   No  CO1.REQ.1857691
# DGSM-DISAN-ARC-HONAC     Nacional                   Si  CO1.REQ.1860431
#
#                           Referencia del Proceso           PCI  \
# Entidad
# GOBERNACION DE SUCRE             CP-SSD-359-2021            ND
# DGSM-DISAN-ARC-HONAC  211-MDN -DISAN-HONAC- 2021  15-01-11-057
#
#                      ID del Portafolio               Nombre del Procedimiento  \
# Entidad
# GOBERNACION DE SUCRE  CO1.BDOS.1807553  PRESTACION DE SERVICIOS PROFESIONALES
# DGSM-DISAN-ARC-HONAC  CO1.BDOS.1810121            ENFERMERA PROFESIONAL HONAC
#
#                                           Descripción del Procedimiento  \
# Entidad
# GOBERNACION DE SUCRE  PRESTACIÓN DE SERVICIOS PROFESIONALES DE UNA F...
# DGSM-DISAN-ARC-HONAC  PRESTACIÓN DE SERVICIOS PROFESIONALES COMO ENF...
#
#                                         Fase Fecha de Publicacion del Proceso  \
# Entidad
# GOBERNACION DE SUCRE  Presentación de oferta                              NaN
# DGSM-DISAN-ARC-HONAC  Presentación de oferta                              NaN
#
#                      Fecha de Ultima Publicación  \
# Entidad
# GOBERNACION DE SUCRE                         NaN
# DGSM-DISAN-ARC-HONAC                         NaN
#
#                      Fecha de Publicacion (Fase Planeacion Precalificacion)  \
# Entidad
# GOBERNACION DE SUCRE                                                NaN
# DGSM-DISAN-ARC-HONAC                                                NaN
#
#                      Fecha de Publicacion (Fase Seleccion Precalificacion)  \
# Entidad
# GOBERNACION DE SUCRE                                                NaN
# DGSM-DISAN-ARC-HONAC                                                NaN
#
#                      Fecha de Publicacion (Manifestacion de Interes)  \
# Entidad
# GOBERNACION DE SUCRE                                             NaN
# DGSM-DISAN-ARC-HONAC                                             NaN
#
#                      Fecha de Publicacion (Fase Borrador)  \
# Entidad
# GOBERNACION DE SUCRE                                  NaN
# DGSM-DISAN-ARC-HONAC                                  NaN
#
#                      Fecha de Publicacion (Fase Seleccion)  Precio Base  \
# Entidad
# GOBERNACION DE SUCRE                                   NaN     12000000
# DGSM-DISAN-ARC-HONAC                                   NaN      9360000
#
#                      Modalidad de Contratacion  \
# Entidad
# GOBERNACION DE SUCRE      Contratación directa
# DGSM-DISAN-ARC-HONAC      Contratación directa
#
#                      Justificación Modalidad de Contratación  Duracion  \
# Entidad
# GOBERNACION DE SUCRE                  ServiciosProfesionales         4
# DGSM-DISAN-ARC-HONAC                  ServiciosProfesionales         4
#
#                      Unidad de Duracion Fecha de Recepcion de Respuestas  \
# Entidad
# GOBERNACION DE SUCRE              Meses                              NaN
# DGSM-DISAN-ARC-HONAC              Meses                              NaN
#
#                      Fecha de Apertura de Respuesta  \
# Entidad
# GOBERNACION DE SUCRE                            NaN
# DGSM-DISAN-ARC-HONAC                            NaN
#
#                      Fecha de Apertura Efectiva  \
# Entidad
# GOBERNACION DE SUCRE                        NaN
# DGSM-DISAN-ARC-HONAC                        NaN
#
#                      Ciudad de la Unidad de Contratación  \
# Entidad
# GOBERNACION DE SUCRE                           Sincelejo
# DGSM-DISAN-ARC-HONAC                           Cartagena
#
#                      Nombre de la Unidad de Contratación  \
# Entidad
# GOBERNACION DE SUCRE                 Secretaria de Salud
# DGSM-DISAN-ARC-HONAC                  grupo de contratos
#
#                       Proveedores Invitados  \
# Entidad
# GOBERNACION DE SUCRE                      0
# DGSM-DISAN-ARC-HONAC                      0
#
#                       Proveedores con Invitacion Directa  \
# Entidad
# GOBERNACION DE SUCRE                                   0
# DGSM-DISAN-ARC-HONAC                                   0
#
#                       Visualizaciones del Procedimiento  \
# Entidad
# GOBERNACION DE SUCRE                                  0
# DGSM-DISAN-ARC-HONAC                                  0
#
#                       Proveedores que Manifestaron Interes  \
# Entidad
# GOBERNACION DE SUCRE                                     0
# DGSM-DISAN-ARC-HONAC                                     0
#
#                       Respuestas al Procedimiento  Respuestas Externas  \
# Entidad
# GOBERNACION DE SUCRE                            0                    0
# DGSM-DISAN-ARC-HONAC                            0                    0
#
#                       Conteo de Respuestas a Ofertas  \
# Entidad
# GOBERNACION DE SUCRE                               0
# DGSM-DISAN-ARC-HONAC                               0
#
#                       Proveedores Unicos con Respuestas  Numero de Lotes  \
# Entidad
# GOBERNACION DE SUCRE                                  0                0
# DGSM-DISAN-ARC-HONAC                                  0                0
#
#                      Estado del Procedimiento  ID Estado del Procedimiento  \
# Entidad
# GOBERNACION DE SUCRE              No Definido                           50
# DGSM-DISAN-ARC-HONAC              No Definido                           50
#
#                      Adjudicado ID Adjudicacion CodigoProveedor  \
# Entidad
# GOBERNACION DE SUCRE         No   No Adjudicado   No Adjudicado
# DGSM-DISAN-ARC-HONAC         No   No Adjudicado   No Adjudicado
#
#                      Departamento Proveedor Ciudad Proveedor  \
# Entidad
# GOBERNACION DE SUCRE              No aplica        No aplica
# DGSM-DISAN-ARC-HONAC              No aplica        No aplica
#
#                      Fecha Adjudicacion  Valor Total Adjudicacion  \
# Entidad
# GOBERNACION DE SUCRE                NaN                         0
# DGSM-DISAN-ARC-HONAC                NaN                         0
#
#                      Nombre del Adjudicador Nombre del Proveedor Adjudicado  \
# Entidad
# GOBERNACION DE SUCRE          No Adjudicado                   No Adjudicado
# DGSM-DISAN-ARC-HONAC          No Adjudicado                   No Adjudicado
#
#                      NIT del Proveedor Adjudicado  \
# Entidad
# GOBERNACION DE SUCRE                No Adjudicado
# DGSM-DISAN-ARC-HONAC                No Adjudicado
#
#                      Codigo Principal de Categoria  \
# Entidad
# GOBERNACION DE SUCRE                   V1.80111600
# DGSM-DISAN-ARC-HONAC                   V1.85101601
#
#                      Estado de Apertura del Proceso  \
# Entidad
# GOBERNACION DE SUCRE                        Abierto
# DGSM-DISAN-ARC-HONAC                        Abierto
#
#                                     Tipo de Contrato Subtipo de Contrato  \
# Entidad
# GOBERNACION DE SUCRE  Servicios de aprovisionamiento     No Especificado
# DGSM-DISAN-ARC-HONAC  Servicios de aprovisionamiento     No Especificado
#
#                      Categorias Adicionales  \
# Entidad
# GOBERNACION DE SUCRE                     ND
# DGSM-DISAN-ARC-HONAC                     ND
#
#                                                              URLProceso  \
# Entidad
# GOBERNACION DE SUCRE  https://community.secop.gov.co/Public/Tenderin...
# DGSM-DISAN-ARC-HONAC  https://community.secop.gov.co/Public/Tenderin...
#
#                       Codigo Entidad
# Entidad
# GOBERNACION DE SUCRE       705153054
# DGSM-DISAN-ARC-HONAC       701724114

# %%
columns = [
          'Fecha de Publicacion del Proceso',
          'Fecha de Ultima Publicación',
          ]
df_SECOP0 = df_SECOP.copy()
df_SECOP0 = df_SECOP0[columns]
df_SECOP0
# Out:
#                                                    Fecha de Publicacion del Proceso  \
# Entidad
# DISPENSARIO MEDICO DE MEDELLÍN                                           03/02/2018
# DIRECCION DE SANIDAD EJERCITO DISPENSARIO MEDIC...                       01/19/2018
# INDUSTRIA MILITAR                                                        11/13/2020
# MINISTERIO DE VIVIENDA. CIUDAD Y TERRITORIO                              01/13/2018
# HOSPITAL CENTRAL                                                         01/31/2019
# ...                                                                             ...
# MINISTERIO DE CULTURA                                                    06/03/2020
# SENA HOTELERIA TURISMO Y ALIMENTOS                                       03/02/2020
# MINISTERIO DEL INTERIOR                                                  02/02/2021
# PERSONERIA DE BOGOTA                                                     02/19/2019
# COMPLEJO CARCELARIO Y PENITENCIARIO DE IBAGUE P...                       10/15/2019
#
#                                                    Fecha de Ultima Publicación
# Entidad
# DISPENSARIO MEDICO DE MEDELLÍN                                      03/02/2018
# DIRECCION DE SANIDAD EJERCITO DISPENSARIO MEDIC...                  01/19/2018
# INDUSTRIA MILITAR                                                   11/13/2020
# MINISTERIO DE VIVIENDA. CIUDAD Y TERRITORIO                         01/12/2018
# HOSPITAL CENTRAL                                                    01/31/2019
# ...                                                                        ...
# MINISTERIO DE CULTURA                                               06/03/2020
# SENA HOTELERIA TURISMO Y ALIMENTOS                                  03/02/2020
# MINISTERIO DEL INTERIOR                                             02/01/2021
# PERSONERIA DE BOGOTA                                                02/19/2019
# COMPLEJO CARCELARIO Y PENITENCIARIO DE IBAGUE P...                  10/15/2019
#
# [876768 rows x 2 columns]

# %%
print('Antes de borrar registros: ',df_SECOP0.shape)
for col in df_SECOP0.columns:
    missing = df_SECOP0[col].isnull()
    num_missing = np.sum(missing)
    
    if num_missing > 0:  
        print('created missing indicator for: {}'.format(col))
        df_SECOP0['{}_ismissing'.format(col)] = missing
ismissing_cols = [col for col in df_SECOP0.columns if 'ismissing' in col]
df_SECOP0['num_missing'] = df_SECOP0[ismissing_cols].sum(axis=1)
# Out:
# Antes de borrar registros:  (876768, 2)
# created missing indicator for: Fecha de Publicacion del Proceso
# created missing indicator for: Fecha de Ultima Publicación

# %%
ind_missing = df_SECOP0[df_SECOP0['num_missing'] >= 1].index
df_less_missing_rows = df_SECOP0.drop(ind_missing, axis=0)
df_less_missing_rows = df_less_missing_rows[columns]
print('Antes de borrar registros: ',df_SECOP0.shape)
print('Después de borrar registros: ',df_less_missing_rows.shape)
print('Cantidad registros borrados: ',df_SECOP0.shape[0]-df_less_missing_rows.shape[0])
# Out:
# Antes de borrar registros:  (876768, 5)
# Después de borrar registros:  (873452, 2)
# Cantidad registros borrados:  3316

# %%
import pandas as pd
df_SECOP0['Fecha de Ultima Publicación'] = pd.to_datetime(df_SECOP0['Fecha de Ultima Publicación'])
df_SECOP0['Fecha de Publicacion del Proceso'] = pd.to_datetime(df_SECOP0['Fecha de Publicacion del Proceso'])
df_SECOP0['Diferencia de fechas'] = (df_SECOP0['Fecha de Publicacion del Proceso'] - df_SECOP0['Fecha de Ultima Publicación']).dt.days
print(df_SECOP0['Diferencia de fechas'])
# Out:
# Entidad
# DISPENSARIO MEDICO DE MEDELLÍN                            0.0
# DIRECCION DE SANIDAD EJERCITO DISPENSARIO MEDICO YOPAL    0.0
# INDUSTRIA MILITAR                                         0.0
# MINISTERIO DE VIVIENDA. CIUDAD Y TERRITORIO               1.0
# HOSPITAL CENTRAL                                          0.0
#                                                          ...
# MINISTERIO DE CULTURA                                     0.0
# SENA HOTELERIA TURISMO Y ALIMENTOS                        0.0
# MINISTERIO DEL INTERIOR                                   1.0
# PERSONERIA DE BOGOTA                                      0.0
# COMPLEJO CARCELARIO Y PENITENCIARIO DE IBAGUE PICALEÑA    0.0
# Name: Diferencia de fechas, Length: 876768, dtype: float64

# %%
resumen = pd.to_numeric(df_SECOP0['Diferencia de fechas'])
resumen.describe()
# Out:
# count    876766.000000
# mean          0.143590
# std           0.350674
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           1.000000
# Name: Diferencia de fechas, dtype: float64

# %% [markdown]
# Diria que si amerita conservar ambas variables debido a que sirve para saber que tan frecuente puede llegar a ser los casos en los que tardan entre su publicacion y que se halla emitido por ultima vez.

# %% [markdown]
# ## Punto 2

# %%
columns = [
          'Tipo de Contrato',
          'Subtipo de Contrato',
          ]
df_SECOP0 = df_SECOP.copy()
df_SECOP0 = df_SECOP0[columns]

# %%
print('Antes de borrar registros: ',df_SECOP0.shape)
for col in df_SECOP0.columns:
    missing = df_SECOP0[col].isnull()
    num_missing = np.sum(missing)
    
    if num_missing > 0:  
        print('created missing indicator for: {}'.format(col))
        df_SECOP0['{}_ismissing'.format(col)] = missing
ismissing_cols = [col for col in df_SECOP0.columns if 'ismissing' in col]
df_SECOP0['num_missing'] = df_SECOP0[ismissing_cols].sum(axis=1)
# Out:
# Antes de borrar registros:  (876768, 2)

# %%
ind_missing = df_SECOP0[df_SECOP0['num_missing'] >= 1].index
df_less_missing_rows = df_SECOP0.drop(ind_missing, axis=0)
df_less_missing_rows = df_less_missing_rows[columns]
print('Antes de borrar registros: ',df_SECOP0.shape)
print('Después de borrar registros: ',df_less_missing_rows.shape)
print('Cantidad registros borrados: ',df_SECOP0.shape[0]-df_less_missing_rows.shape[0])
# Out:
# Antes de borrar registros:  (876768, 3)
# Después de borrar registros:  (876768, 2)
# Cantidad registros borrados:  0

# %%
from pandas.core.reshape.pivot import crosstab
microsstab = pd.crosstab(df_SECOP0['Tipo de Contrato'],df_SECOP0['Subtipo de Contrato'])
microsstab
# Out:
# Subtipo de Contrato             No Especificado
# Tipo de Contrato
# 27 - Otros servicios                      42777
# Acuerdo Marco                              2782
# Alquiler de edificios                      7554
# Arrendamiento Muebles                       527
# Comisión                                     84
# Compraventa                               42412
# Concesión                                   108
# Consultoría                                4164
# Decreto 092 de 2017                       28466
# Interventoría                              4725
# ND                                        28827
# No Especificado                               5
# Obra                                      11790
# Seguros                                    2218
# Servicios de aprovisionamiento           653206
# Suministros                               46985
# Ventas de muebles                           138

# %% [markdown]
# Se concluye que no es necesaria la variable Subtipo de Contrato debido a que todos los subcontratos son No especificados.

# %% [markdown]
# ## Punto 3

# %%
df_SECOP[['Unidad de Duracion','Duracion']]

columns = [
          'Unidad de Duracion',
           'Duracion'
          ]
df_SECOP0 = df_SECOP.copy()
df_SECOP0 = df_SECOP0[columns]
df_SECOP0
# Out:
#                                                    Unidad de Duracion  \
# Entidad
# DISPENSARIO MEDICO DE MEDELLÍN                                   Dias
# DIRECCION DE SANIDAD EJERCITO DISPENSARIO MEDIC...               Dias
# INDUSTRIA MILITAR                                               Meses
# MINISTERIO DE VIVIENDA. CIUDAD Y TERRITORIO                        ND
# HOSPITAL CENTRAL                                                 Dias
# ...                                                               ...
# MINISTERIO DE CULTURA                                            Dias
# SENA HOTELERIA TURISMO Y ALIMENTOS                               Dias
# MINISTERIO DEL INTERIOR                                         Meses
# PERSONERIA DE BOGOTA                                             Dias
# COMPLEJO CARCELARIO Y PENITENCIARIO DE IBAGUE P...               Dias
#
#                                                     Duracion
# Entidad
# DISPENSARIO MEDICO DE MEDELLÍN                            30
# DIRECCION DE SANIDAD EJERCITO DISPENSARIO MEDIC...       344
# INDUSTRIA MILITAR                                          7
# MINISTERIO DE VIVIENDA. CIUDAD Y TERRITORIO                0
# HOSPITAL CENTRAL                                         150
# ...                                                      ...
# MINISTERIO DE CULTURA                                    203
# SENA HOTELERIA TURISMO Y ALIMENTOS                       286
# MINISTERIO DEL INTERIOR                                    6
# PERSONERIA DE BOGOTA                                     336
# COMPLEJO CARCELARIO Y PENITENCIARIO DE IBAGUE P...        60
#
# [876768 rows x 2 columns]

# %%
print('Antes de borrar registros: ',df_SECOP0.shape)
for col in df_SECOP0.columns:
    missing = df_SECOP0[col].isnull()
    num_missing = np.sum(missing)
    
    if num_missing > 0:  
        print('created missing indicator for: {}'.format(col))
        df_SECOP0['{}_ismissing'.format(col)] = missing
ismissing_cols = [col for col in df_SECOP0.columns if 'ismissing' in col]
df_SECOP0['num_missing'] = df_SECOP0[ismissing_cols].sum(axis=1)
# Out:
# Antes de borrar registros:  (876768, 2)

# %%
ind_missing = df_SECOP0[df_SECOP0['num_missing'] >= 1].index
df_less_missing_rows = df_SECOP0.drop(ind_missing, axis=0)
df_less_missing_rows = df_less_missing_rows[columns]
print('Antes de borrar registros: ',df_SECOP0.shape)
print('Después de borrar registros: ',df_less_missing_rows.shape)
print('Cantidad registros borrados: ',df_SECOP0.shape[0]-df_less_missing_rows.shape[0])
# Out:
# Antes de borrar registros:  (876768, 3)
# Después de borrar registros:  (876768, 2)
# Cantidad registros borrados:  0

# %%
df_SECOP0["Duracion_mes->dias"] = np.where(df_SECOP0["Unidad de Duracion"] == "Meses", df_SECOP0["Duracion"]*30,  df_SECOP0["Duracion"])
df_SECOP0.sample(20)
# Out:
#                                                    Unidad de Duracion  \
# Entidad
# SECRETARIA DISTRITAL DE SEGURIDAD, CONVIVENCIA ...              Meses
# SUBRED INTEGRADA DE SERVICIOS DE SALUD NORTE E....              Meses
# INSTITUTO PARA LA INVESTIGACIÓN EDUCATIVA Y EL ...               Dias
# PERSONERIA DE BOGOTA                                            Meses
# ICBF REGIONAL CORDOBA                                              ND
# SENA REGIONAL ATLANTICO                                          Dias
# ALCALDIA LOCAL DE BOSA                                          Meses
# RESGUARDO INDIGENA KANKUAMO                                     Meses
# EMPRESA COLOMBIANA DE PETROLEOS                                  Dias
# DANE - TERRITORIAL CENTRO ORIENTE                                Dias
# MUNICIPIO DE PEREIRA-OFICIAL                                     Dias
# SECRETARÍA DISTRITAL DE MOVILIDAD                               Meses
# AGENCIA NACIONAL DE CONTRATACIÓN PÚBLICA -COLOM...               Años
# SECRETARIA DISTRITAL DE AMBIENTE                                Meses
# DEPARTAMENTO ADMINISTRATIVO DE LA DEFENSORIA DE...              Meses
# DANE - TERRITORIAL CENTRO ORIENTE                                Dias
# COMISION COLOMBIANA DEL OCEANO                                   Dias
# INSTITUTO DISTRITAL DE TURISMO                                  Meses
# DEPARTAMENTO NACIONAL DE PLANEACION                              Dias
# MUNICIPIO DE NEIVA                                               Dias
#
#                                                     Duracion  num_missing  \
# Entidad
# SECRETARIA DISTRITAL DE SEGURIDAD, CONVIVENCIA ...        10          0.0
# SUBRED INTEGRADA DE SERVICIOS DE SALUD NORTE E....         2          0.0
# INSTITUTO PARA LA INVESTIGACIÓN EDUCATIVA Y EL ...        75          0.0
# PERSONERIA DE BOGOTA                                       5          0.0
# ICBF REGIONAL CORDOBA                                      0          0.0
# SENA REGIONAL ATLANTICO                                  130          0.0
# ALCALDIA LOCAL DE BOSA                                     2          0.0
# RESGUARDO INDIGENA KANKUAMO                                6          0.0
# EMPRESA COLOMBIANA DE PETROLEOS                          240          0.0
# DANE - TERRITORIAL CENTRO ORIENTE                         52          0.0
# MUNICIPIO DE PEREIRA-OFICIAL                              41          0.0
# SECRETARÍA DISTRITAL DE MOVILIDAD                         10          0.0
# AGENCIA NACIONAL DE CONTRATACIÓN PÚBLICA -COLOM...         3          0.0
# SECRETARIA DISTRITAL DE AMBIENTE                          13          0.0
# DEPARTAMENTO ADMINISTRATIVO DE LA DEFENSORIA DE...         5          0.0
# DANE - TERRITORIAL CENTRO ORIENTE                        180          0.0
# COMISION COLOMBIANA DEL OCEANO                           300          0.0
# INSTITUTO DISTRITAL DE TURISMO                             4          0.0
# DEPARTAMENTO NACIONAL DE PLANEACION                      340          0.0
# MUNICIPIO DE NEIVA                                        90          0.0
#
#                                                     Duracion_mes->dias
# Entidad
# SECRETARIA DISTRITAL DE SEGURIDAD, CONVIVENCIA ...                 300
# SUBRED INTEGRADA DE SERVICIOS DE SALUD NORTE E....                  60
# INSTITUTO PARA LA INVESTIGACIÓN EDUCATIVA Y EL ...                  75
# PERSONERIA DE BOGOTA                                               150
# ICBF REGIONAL CORDOBA                                                0
# SENA REGIONAL ATLANTICO                                            130
# ALCALDIA LOCAL DE BOSA                                              60
# RESGUARDO INDIGENA KANKUAMO                                        180
# EMPRESA COLOMBIANA DE PETROLEOS                                    240
# DANE - TERRITORIAL CENTRO ORIENTE                                   52
# MUNICIPIO DE PEREIRA-OFICIAL                                        41
# SECRETARÍA DISTRITAL DE MOVILIDAD                                  300
# AGENCIA NACIONAL DE CONTRATACIÓN PÚBLICA -COLOM...                   3
# SECRETARIA DISTRITAL DE AMBIENTE                                   390
# DEPARTAMENTO ADMINISTRATIVO DE LA DEFENSORIA DE...                 150
# DANE - TERRITORIAL CENTRO ORIENTE                                  180
# COMISION COLOMBIANA DEL OCEANO                                     300
# INSTITUTO DISTRITAL DE TURISMO                                     120
# DEPARTAMENTO NACIONAL DE PLANEACION                                340
# MUNICIPIO DE NEIVA                                                  90

# %%
df_SECOP0["Duracion_años->dias"] = np.where(df_SECOP0["Unidad de Duracion"] == "Años", df_SECOP0["Duracion"]*365,  df_SECOP0["Duracion"])
df_SECOP0
# Out:
#                                                    Unidad de Duracion  \
# Entidad
# DISPENSARIO MEDICO DE MEDELLÍN                                   Dias
# DIRECCION DE SANIDAD EJERCITO DISPENSARIO MEDIC...               Dias
# INDUSTRIA MILITAR                                               Meses
# MINISTERIO DE VIVIENDA. CIUDAD Y TERRITORIO                        ND
# HOSPITAL CENTRAL                                                 Dias
# ...                                                               ...
# MINISTERIO DE CULTURA                                            Dias
# SENA HOTELERIA TURISMO Y ALIMENTOS                               Dias
# MINISTERIO DEL INTERIOR                                         Meses
# PERSONERIA DE BOGOTA                                             Dias
# COMPLEJO CARCELARIO Y PENITENCIARIO DE IBAGUE P...               Dias
#
#                                                     Duracion  num_missing  \
# Entidad
# DISPENSARIO MEDICO DE MEDELLÍN                            30          0.0
# DIRECCION DE SANIDAD EJERCITO DISPENSARIO MEDIC...       344          0.0
# INDUSTRIA MILITAR                                          7          0.0
# MINISTERIO DE VIVIENDA. CIUDAD Y TERRITORIO                0          0.0
# HOSPITAL CENTRAL                                         150          0.0
# ...                                                      ...          ...
# MINISTERIO DE CULTURA                                    203          0.0
# SENA HOTELERIA TURISMO Y ALIMENTOS                       286          0.0
# MINISTERIO DEL INTERIOR                                    6          0.0
# PERSONERIA DE BOGOTA                                     336          0.0
# COMPLEJO CARCELARIO Y PENITENCIARIO DE IBAGUE P...        60          0.0
#
#                                                     Duracion_mes->dias  \
# Entidad
# DISPENSARIO MEDICO DE MEDELLÍN                                      30
# DIRECCION DE SANIDAD EJERCITO DISPENSARIO MEDIC...                 344
# INDUSTRIA MILITAR                                                  210
# MINISTERIO DE VIVIENDA. CIUDAD Y TERRITORIO                          0
# HOSPITAL CENTRAL                                                   150
# ...                                                                ...
# MINISTERIO DE CULTURA                                              203
# SENA HOTELERIA TURISMO Y ALIMENTOS                                 286
# MINISTERIO DEL INTERIOR                                            180
# PERSONERIA DE BOGOTA                                               336
# COMPLEJO CARCELARIO Y PENITENCIARIO DE IBAGUE P...                  60
#
#                                                     Duracion_años->dias
# Entidad
# DISPENSARIO MEDICO DE MEDELLÍN                                       30
# DIRECCION DE SANIDAD EJERCITO DISPENSARIO MEDIC...                  344
# INDUSTRIA MILITAR                                                     7
# MINISTERIO DE VIVIENDA. CIUDAD Y TERRITORIO                           0
# HOSPITAL CENTRAL                                                    150
# ...                                                                 ...
# MINISTERIO DE CULTURA                                               203
# SENA HOTELERIA TURISMO Y ALIMENTOS                                  286
# MINISTERIO DEL INTERIOR                                               6
# PERSONERIA DE BOGOTA                                                336
# COMPLEJO CARCELARIO Y PENITENCIARIO DE IBAGUE P...                   60
#
# [876768 rows x 5 columns]
